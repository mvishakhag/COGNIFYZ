# %% [markdown]
# <a href="https://colab.research.google.com/github/mvishakhag/COGNIFYZ/blob/main/Cognifyz_L_3_T_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Level 3 - Task 2 (Votes Analysis):**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-39c9ebdb-7bba-4188-9e7e-63b0fd5c61d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39c9ebdb-7bba-4188-9e7e-63b0fd5c61d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename = list(uploaded.keys())[0]
df = pd.read_csv(filename)

# %%
highest_votes_restaurant = df.loc[df["Votes"].idxmax(), ["Restaurant Name", "Votes"]]
lowest_votes_restaurant = df.loc[df["Votes"].idxmin(), ["Restaurant Name", "Votes"]]

print(f"🏆 Restaurant with Highest Votes: {highest_votes_restaurant['Restaurant Name']} ({highest_votes_restaurant['Votes']} votes)")
print(f"⚠ Restaurant with Lowest Votes: {lowest_votes_restaurant['Restaurant Name']} ({lowest_votes_restaurant['Votes']} votes)")
# Out:
# 🏆 Restaurant with Highest Votes: Toit (10934 votes)
# ⚠ Restaurant with Lowest Votes: Cantinho da Gula (0 votes)

# %%
correlation = df["Votes"].corr(df["Aggregate rating"])
print(f"\n📊 Correlation between Votes and Ratings: {correlation:.2f}")
# Out:
# 📊 Correlation between Votes and Ratings: 0.31

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=df["Votes"], y=df["Aggregate rating"], alpha=0.5, color="blue")

plt.xlabel("Number of Votes")
plt.ylabel("Aggregate Rating")
plt.title("Votes vs. Ratings")
plt.grid(True)

plt.show()
